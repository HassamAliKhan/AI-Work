# %%
import math
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
df_train=pd.read_csv('/content/sample_data/california_housing_train.csv')
df_test=pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
x=df_train.iloc[:,[0,1,2,3,4,5,6,7]]
y=df_train.iloc[:,-1]

# %%
x_test=df_test.iloc[:,[0,1,2,3,4,5,6,7]]

# %%
y_test=df_test.iloc[:,-1]

# %%
input_size=len(x.columns)

# %%
input_size
# Out:
# 8

# %%
output_size=1

# %%
from tensorflow.keras.optimizers import Adam
#Adaptive Movement Estimation

# %%
models=tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size)
])
custom_optimizer=tf.keras.optimizers.SGD(learning_rate=0.02)
models.compile(optimizer='Adam',loss='mean_squared_error')
models.fit(x,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 1s 1ms/step - loss: 56303665152.0000
# Epoch 2/100
# 532/532 [==============================] - 1s 1ms/step - loss: 55140450304.0000
# Epoch 3/100
# 532/532 [==============================] - 1s 1ms/step - loss: 54012870656.0000
# Epoch 4/100
# 532/532 [==============================] - 1s 1ms/step - loss: 52913602560.0000
# Epoch 5/100
# 532/532 [==============================] - 1s 1ms/step - loss: 51840675840.0000
# Epoch 6/100
# 532/532 [==============================] - 1s 1ms/step - loss: 50796720128.0000
# Epoch 7/100
# 532/532 [==============================] - 1s 1ms/step - loss: 49778483200.0000
# Epoch 8/100
# 532/532 [==============================] - 1s 1ms/step - loss: 48785076224.0000
# Epoch 9/100
# 532/532 [==============================] - 1s 1ms/step - loss: 47816744960.0000
# Epoch 10/100
# 532/532 [==============================] - 1s 1ms/step - loss: 46872199168.0000
# Epoch 11/100
# ...

# %%
models1=tf.keras.Sequential([
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(output_size)
])
custom_optimizer=tf.keras.optimizers.SGD(learning_rate=0.02)
models1.compile(optimizer='Adam',loss='mean_squared_error')
models1.fit(x,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 2s 3ms/step - loss: 39662317568.0000
# Epoch 2/100
# 532/532 [==============================] - 1s 2ms/step - loss: 26096846848.0000
# Epoch 3/100
# 532/532 [==============================] - 1s 2ms/step - loss: 24473038848.0000
# Epoch 4/100
# 532/532 [==============================] - 1s 2ms/step - loss: 20983326720.0000
# Epoch 5/100
# 532/532 [==============================] - 1s 2ms/step - loss: 13944657920.0000
# Epoch 6/100
# 532/532 [==============================] - 1s 2ms/step - loss: 11432084480.0000
# Epoch 7/100
# 532/532 [==============================] - 1s 2ms/step - loss: 11268642816.0000
# Epoch 8/100
# 532/532 [==============================] - 1s 2ms/step - loss: 11107837952.0000
# Epoch 9/100
# 532/532 [==============================] - 1s 2ms/step - loss: 10974054400.0000
# Epoch 10/100
# 532/532 [==============================] - 1s 2ms/step - loss: 10842222592.0000
# Epoch 11/100
# ...

# %%
models2=tf.keras.Sequential([
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(512,activation='relu'),
                            tf.keras.layers.Dense(512,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(output_size)
])
custom_optimizer=tf.keras.optimizers.SGD(learning_rate=0.02)
models2.compile(optimizer='Adam',loss='mean_squared_error')
models2.fit(x,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 6s 10ms/step - loss: 17444599808.0000
# Epoch 2/100
# 532/532 [==============================] - 5s 10ms/step - loss: 9411602432.0000
# Epoch 3/100
# 532/532 [==============================] - 6s 11ms/step - loss: 8529121280.0000
# Epoch 4/100
# 532/532 [==============================] - 5s 10ms/step - loss: 7870384640.0000
# Epoch 5/100
# 532/532 [==============================] - 7s 12ms/step - loss: 7344892416.0000
# Epoch 6/100
# 532/532 [==============================] - 8s 16ms/step - loss: 6887729152.0000
# Epoch 7/100
# 532/532 [==============================] - 5s 10ms/step - loss: 6445326336.0000
# Epoch 8/100
# 532/532 [==============================] - 6s 11ms/step - loss: 6302573056.0000
# Epoch 9/100
# 532/532 [==============================] - 5s 10ms/step - loss: 5864825856.0000
# Epoch 10/100
# 532/532 [==============================] - 5s 10ms/step - loss: 5595422208.0000
# Epoch 11/100
# ...

# %%
models3=tf.keras.Sequential([
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(64,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(512,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(64,activation='relu'),
                            tf.keras.layers.Dense(64,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            
                            tf.keras.layers.Dense(output_size)
])
custom_optimizer=tf.keras.optimizers.SGD(learning_rate=0.02)
models3.compile(optimizer='Adam',loss='mean_squared_error')
models3.fit(x,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 5s 8ms/step - loss: 23677120512.0000
# Epoch 2/100
# 532/532 [==============================] - 4s 8ms/step - loss: 11550781440.0000
# Epoch 3/100
# 532/532 [==============================] - 4s 8ms/step - loss: 10615864320.0000
# Epoch 4/100
# 532/532 [==============================] - 4s 8ms/step - loss: 9917145088.0000
# Epoch 5/100
# 532/532 [==============================] - 4s 8ms/step - loss: 9621605376.0000
# Epoch 6/100
# 532/532 [==============================] - 4s 8ms/step - loss: 9094736896.0000
# Epoch 7/100
# 532/532 [==============================] - 4s 8ms/step - loss: 8737673216.0000
# Epoch 8/100
# 532/532 [==============================] - 4s 8ms/step - loss: 8372731904.0000
# Epoch 9/100
# 532/532 [==============================] - 4s 8ms/step - loss: 7994497536.0000
# Epoch 10/100
# 532/532 [==============================] - 4s 8ms/step - loss: 7563573248.0000
# Epoch 11/100
# ...

# %%
models4=tf.keras.Sequential([
                            tf.keras.layers.Dense(8,activation='relu'),
                            tf.keras.layers.Dense(64,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(512,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(256,activation='relu'),
                            tf.keras.layers.Dense(128,activation='relu'),
                            tf.keras.layers.Dense(8,activation='relu'),
                            
                            tf.keras.layers.Dense(output_size)
])
custom_optimizer=tf.keras.optimizers.SGD(learning_rate=0.02)
models4.compile(optimizer='Adam',loss='mean_squared_error')
models4.fit(x,y,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 532/532 [==============================] - 5s 8ms/step - loss: 25320321024.0000
# Epoch 2/100
# 532/532 [==============================] - 4s 7ms/step - loss: 13448624128.0000
# Epoch 3/100
# 532/532 [==============================] - 4s 8ms/step - loss: 11716624384.0000
# Epoch 4/100
# 532/532 [==============================] - 4s 8ms/step - loss: 10501937152.0000
# Epoch 5/100
# 532/532 [==============================] - 4s 8ms/step - loss: 9675503616.0000
# Epoch 6/100
# 532/532 [==============================] - 4s 7ms/step - loss: 8940305408.0000
# Epoch 7/100
# 532/532 [==============================] - 4s 8ms/step - loss: 8483623424.0000
# Epoch 8/100
# 532/532 [==============================] - 4s 8ms/step - loss: 8060702208.0000
# Epoch 9/100
# 532/532 [==============================] - 4s 7ms/step - loss: 7904833536.0000
# Epoch 10/100
# 532/532 [==============================] - 4s 7ms/step - loss: 7799344640.0000
# Epoch 11/100
# ...

# %%
y_pred=models.predict(x_test)
fig=plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred))
# Out:
# MAE 114258.21953808593

# %%
y_pred1=models1.predict(x_test)
fig=plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred1)

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred1))
# Out:
# MAE 51028.894634114586

# %%
from sklearn import metrics

# %%
y_pred2=models2.predict(x_test)
fig=plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred2)

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred2))
# Out:
# MAE 48485.6649609375

# %%
y_pred3=models3.predict(x_test)
fig=plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred3)

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred3))
# Out:
# MAE 53618.24149479167

# %%
y_pred4=models4.predict(x_test)
fig=plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred4)

# %%
print('MAE',metrics.mean_absolute_error(y_test,y_pred4))
# Out:
# MAE 47941.08929166666

# %%
print(y_pred[0:3])
print(y_test[0:3])
# Out:
# [[177223.19]
#  [ 82129.68]
#  [160966.81]]
# 0    344700.0
# 1    176500.0
# 2    270500.0
# Name: median_house_value, dtype: float64

# %%
print(y_pred1[0:5])
print(y_test[0:5])
# Out:
# [[337374.88]
#  [189938.42]
#  [294472.47]
#  [259117.8 ]
#  [101744.04]]
# 0    344700.0
# 1    176500.0
# 2    270500.0
# 3    330000.0
# 4     81700.0
# Name: median_house_value, dtype: float64

# %%
print(y_pred2[0:3])
print(y_test[0:3])
# Out:
# [[422095.06]
#  [213468.28]
#  [306972.3 ]]
# 0    344700.0
# 1    176500.0
# 2    270500.0
# Name: median_house_value, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test, squared=False)
# Out:
# 156448.87120628165

# %%
plt.scatter(np.squeeze(models.predict_on_batch(x)),np.squeeze(y),c='#88c999')
plt.xlabel('Input')
plt.ylabel('Predicted Output')
plt.show()
